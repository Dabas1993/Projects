# %% [markdown]
# ### Basic Cleaning of Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Diwali Sales Data.csv", encoding = 'unicode_escape')

# %%
df.shape
# Out:
# (6319, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6319 entries, 0 to 6318
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           6319 non-null   int64
#  1   Cust_name         6319 non-null   object
#  2   Product_ID        6319 non-null   object
#  3   Gender            6319 non-null   object
#  4   Age Group         6319 non-null   object
#  5   Age               6319 non-null   int64
#  6   Marital_Status    6319 non-null   int64
#  7   State             6319 non-null   object
#  8   Zone              6319 non-null   object
#  9   Occupation        6319 non-null   object
#  10  Product_Category  6319 non-null   object
#  11  Orders            6319 non-null   int64
#  12  Amount            6307 non-null   float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 740.6+ KB

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
pd.isnull(df)
# Out:
#       User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0       False      False       False   False      False  False
# 1       False      False       False   False      False  False
# 2       False      False       False   False      False  False
# 3       False      False       False   False      False  False
# 4       False      False       False   False      False  False
# ...       ...        ...         ...     ...        ...    ...
# 6314    False      False       False   False      False  False
# 6315    False      False       False   False      False  False
# 6316    False      False       False   False      False  False
# 6317    False      False       False   False      False  False
# 6318    False      False       False   False      False  False
#
#       Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0              False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.shape
# Out:
# (6319, 13)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (6307, 13)

# %%
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns = {"Marital_Status": "Shaadi"})
# To rename the columns
# Out:
#       User_ID  Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0     1002903  Sanskriti  P00125942      F     26-35   28       0
# 1     1000732     Kartik  P00110942      F     26-35   35       1
# 2     1001990      Bindu  P00118542      F     26-35   35       1
# 3     1001425     Sudevi  P00237842      M      0-17   16       0
# 4     1000588       Joni  P00057942      M     26-35   28       1
# ...       ...        ...        ...    ...       ...  ...     ...
# 6314  1005026      Stuti  P00226242      F     26-35   31       1
# 6315  1002691     Pierre  P00237642      F     18-25   21       1
# 6316  1003609     Sewall  P00247042      M     26-35   26       0
# 6317  1000504     Poddar  P00229942      F     26-35   33       0
# 6318  1000647       Nida  P00033042      F     36-45   42       0
#
#                  State      Zone       Occupation       Product_Category  \
# 0          Maharashtra   Western       Healthcare                   Auto
# ...

# %%
df.describe()
# Out:
#             User_ID          Age  Marital_Status       Orders        Amount
# count  6.307000e+03  6307.000000     6307.000000  6307.000000   6307.000000
# mean   1.002986e+06    35.695735        0.412875     2.473918  12995.275408
# std    1.709891e+03    12.779021        0.492390     1.111202   4119.187983
# min    1.000003e+06    12.000000        0.000000     1.000000   7866.000000
# 25%    1.001482e+06    27.000000        0.000000     1.000000   8878.500000
# 50%    1.003051e+06    33.000000        0.000000     2.000000  12044.000000
# 75%    1.004408e+06    44.000000        1.000000     3.000000  16092.000000
# max    1.006040e+06    92.000000        1.000000     4.000000  23952.000000

# %%
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                Age       Orders        Amount
# count  6307.000000  6307.000000   6307.000000
# mean     35.695735     2.473918  12995.275408
# std      12.779021     1.111202   4119.187983
# min      12.000000     1.000000   7866.000000
# 25%      27.000000     1.000000   8878.500000
# 50%      33.000000     2.000000  12044.000000
# 75%      44.000000     3.000000  16092.000000
# max      92.000000     4.000000  23952.000000

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(x = "Gender", data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by = 'Amount', ascending=False)
# Out:
#   Gender    Amount
# 0      F  57227939
# 1      M  24733263

# %%
sales_gen = df.groupby(['Gender'], as_index=False)["Amount"].sum().sort_values(by='Amount', ascending = False)
sns.barplot(x="Gender", y='Amount', data= sales_gen)
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='Amount'>

# %%
# From above graph, we clearly said that most of the buyers are femaled and even the purchasing power of females are greater than male

# %% [markdown]
# ### Purchasing power depend on age

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(data = df, x= 'Age Group', hue = "Gender")
# Out:
# <AxesSubplot: xlabel='Age Group', ylabel='count'>

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending = False)
sns.barplot(x = 'Age Group', y= 'Amount', data = sales_age)
# Out:
# <AxesSubplot: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# #### From above graphs we can see that most of the buyers are age of group between 26- 35 yeas females

# %% [markdown]
# ## State

# %%
# Total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index = False)['Orders'].sum().sort_values(by = 'Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(25,5)})
sns.barplot(data = sales_state, x = 'State', y = 'Orders')
# Out:
# <AxesSubplot: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states


sales_state = df.groupby(['State'], as_index = False)['Amount'].sum().sort_values(by = 'Amount', ascending=False)
sns.set(rc={'figure.figsize':(25,5)})
sns.barplot(data = sales_state, x = 'State', y = 'Amount')
# Out:
# <AxesSubplot: xlabel='State', ylabel='Amount'>

# %% [markdown]
# #### From above graphs we can we that most of the orders & total sales/amount are from Uttar Pradesh, Maharastra and Kerala respectively

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data =df, x = "Marital_Status")
sns.set(rc={"figure.figsize":(4,5)})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by = ['Amount'], ascending = False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x='Marital_Status', y="Amount", hue = 'Gender')
# Out:
# <AxesSubplot: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are maried (women) and they have high purchasing power

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = "Occupation")

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index= False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = "Occupation", y = 'Amount')
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are working in IT, Aviation and Helthcare sector

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax= sns.countplot(data = df, x= "Product_Category")

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by = ['Amount'], ascending = False). head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category', y= 'Amount')
# Out:
# <AxesSubplot: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the sold prodcuts are from Food, Clothing and Electrnoics category

# %%
sales_state = df.groupby(['Product_ID'], as_index = False)['Orders'].sum().sort_values(by = 'Orders', ascending = False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = "Product_ID", y="Orders")
# Out:
# <AxesSubplot: xlabel='Product_ID', ylabel='Orders'>

# %%
# Top 10 most sold products (same as above)

fig1, ax1 = plt.subplots(figsize = (12,7))
df.groupby("Product_ID")['Orders'].sum().nlargest(10).sort_values(ascending = False).plot(kind = "bar")
# Out:
# <AxesSubplot: xlabel='Product_ID'>

# %% [markdown]
# ## Conclusion:-

# %% [markdown]
# Married Women age group 26-35 years from U.P., Maharastra and Karnatka wokring in IT, Healthcare and Aviation are more likely to buy products from food, clothing and electronics category
